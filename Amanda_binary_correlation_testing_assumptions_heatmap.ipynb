# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn import preprocessing

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from matplotlib import pyplot as plt

import seaborn as sns

# %% [markdown]
# # New Section

# %%
table = pd.read_csv("Precinct - Combined.csv")
table.head()
# Out:
#    Unnamed: 0  ... Polling Sites
# 0           1  ...             1
# 1           2  ...             1
# 2           3  ...             1
# 3           4  ...             1
# 4           5  ...             1
#
# [5 rows x 17 columns]

# %%
X = table.iloc[:,table.columns != 'Population Density: Hispanic']
y = table.iloc[:,table.columns!='Polling Sites']

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=2, random_state=5)

# %% [markdown]
# Generated a heatmap to test for multicollinearity in order to see whether the data set satisfy the assumption to carry out a binary logistic regression. Correlation between the independent variables will range from 0 to 1, with 1 being the highest level of correlation.
#
# Leavitt, C., 2019. [online] Available at: <https://towardsdatascience.com/multicollinearity-why-is-it-a-problem-398b010b77ac> .

# %%
plt.figure(figsize = (38,16))
sns.heatmap(table.corr(), annot = True)
plt.savefig('heatmap.png')
plt.show()

# %%
data = table.drop(columns="Polling Sites")
table.head()
# Out:
#    Unnamed: 0  ... Polling Sites
# 0           1  ...             1
# 1           2  ...             1
# 2           3  ...             1
# 3           4  ...             1
# 4           5  ...             1
#
# [5 rows x 17 columns]
